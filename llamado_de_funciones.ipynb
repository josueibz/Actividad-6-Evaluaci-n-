# %%
import funciones as fn

# %%
df = fn.cargar_excel_csv('Copia de Bologna_Italia.csv')
df.head()
# Out:
#        id     scrape_id last_scraped       source  host_id host_since  \
# 0   46352  2.024120e+13     20/12/24  city scrape   467810   28/03/11
# 1   59697  2.024120e+13     20/12/24  city scrape   286688   14/11/10
# 2   85368  2.024120e+13     20/12/24  city scrape   467675   28/03/11
# 3  219878  2.024120e+13     20/12/24  city scrape  1139326   10/09/11
# 4  229114  2.024120e+13     20/12/24  city scrape  1196205   22/09/11
#
#   host_response_time host_response_rate host_acceptance_rate  \
# 0       within a day                75%                  47%
# 1       within a day                50%                  50%
# 2     within an hour                86%                  73%
# 3     within an hour               100%                  95%
# 4     within an hour               100%                 100%
#
#   host_is_superhost  ...  review_scores_communication review_scores_location  \
# 0                 f  ...                         4.85                   4.84
# ...

# %%
df[df.columns[0]] = df[df.columns[0]].astype(str) 
df[df.columns[1]] = df[df.columns[1]].astype(str)
df[df.columns[4]] = df[df.columns[4]].astype(str)

# %%
valores_nulos = fn.contar_nulos(df)
valores_nulos
# Out:
# ('Nulos por columna:',
#  id                                                 0
#  scrape_id                                          0
#  last_scraped                                       0
#  source                                             0
#  host_id                                            0
#  host_since                                         0
#  host_response_time                               470
#  host_response_rate                               470
#  host_acceptance_rate                             214
#  host_is_superhost                                151
#  host_listings_count                                0
#  host_has_profile_pic                               0
#  host_identity_verified                             0
#  neighbourhood_cleansed                             0
#  latitude                                           0
#  longitude                                          0
#  property_type                                      0
# ...

# %%
df = fn.sustitucion_nulos(df)
df
# Out:
#       host_listings_count  longitude  bathrooms  beds  maximum_nights  \
# 0                       2  11.333980        1.0   1.0             730
# 1                       2  11.341240        1.0   2.0            1125
# 2                       1  11.356250        2.0   5.0              30
# 3                       2  11.353920        1.0   1.0             180
# 4                       1  11.349570        1.0   4.0              60
# ...                   ...        ...        ...   ...             ...
# 4663                    1  11.348268        2.0   4.0             365
# 4664                    8  11.294941        1.0   3.0             365
# 4665                  179  11.386438        1.0   2.0            1125
# 4666                    1  11.368937        1.0   4.0              30
# 4667                    1  11.371063        1.0   1.0             365
#
#       availability_60  availability_365  number_of_reviews_ltm  \
# ...

# %%
valores_nulos = fn.contar_nulos(df)
valores_nulos
# Out:
# ('Nulos por columna:',
#  host_listings_count                             0
#  longitude                                       0
#  bathrooms                                       0
#  beds                                            0
#  maximum_nights                                  0
#  availability_60                                 0
#  availability_365                                0
#  number_of_reviews_ltm                           0
#  review_scores_rating                            0
#  review_scores_cleanliness                       0
#  review_scores_communication                     0
#  review_scores_value                             0
#  calculated_host_listings_count_entire_homes     0
#  calculated_host_listings_count_shared_rooms     0
#  latitude                                        0
#  accommodates                                    0
#  bedrooms                                        0
#  minimum_nights                                  0
# ...

# %%
df = fn.sustituir_atipicos(df)
df
# Out:
# Limite superior permitido host_listings_count                              26.000000
# longitude                                        11.376946
# bathrooms                                         1.000000
# beds                                              3.750000
# maximum_nights                                  869.000000
# availability_60                                  95.500000
# availability_365                                587.500000
# number_of_reviews_ltm                            51.000000
# review_scores_rating                              5.305000
# review_scores_cleanliness                         5.335000
# review_scores_communication                       5.275000
# review_scores_value                               5.295000
# calculated_host_listings_count_entire_homes      13.500000
# calculated_host_listings_count_shared_rooms       0.000000
# latitude                                         44.518520
# ...

# %%
valores_nulos = fn.contar_nulos(df)
valores_nulos
# Out:
# ('Nulos por columna:',
#  id                                              0
#  scrape_id                                       0
#  last_scraped                                    0
#  source                                          0
#  host_id                                         0
#  host_since                                      0
#  host_response_time                              0
#  host_response_rate                              0
#  host_acceptance_rate                            0
#  host_is_superhost                               0
#  host_has_profile_pic                            0
#  host_identity_verified                          0
#  neighbourhood_cleansed                          0
#  property_type                                   0
#  room_type                                       0
#  bathrooms_text                                  0
#  amenities                                       0
#  price                                           0
# ...

# %%
df.to_csv('Bologna_Italia_evaluacion.csv')
